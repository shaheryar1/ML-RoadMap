# %%
# %config IPCompleter.greedy=True

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('samples/water_colors.png')
img = img[:,:,::-1]
img_show=img.copy()
blur = cv2.GaussianBlur(img,(5,5),0)

# %%
fig,ax=plt.subplots(1,2,figsize=(20, 20))
ax[0].imshow(img)
ax[1].imshow(blur)

# %%
r= ([150,0,0],[255,30,30])
lower = np.array(r[0], dtype="uint8")
upper = np.array(r[1], dtype="uint8")
lower
# Out:
# array([150,   0,   0], dtype=uint8)

# %%
mask = cv2.inRange(img, lower, upper)

# %%
output = cv2.bitwise_and(img, img, mask=mask)

# %%
dilated=cv2.dilate(output,None,iterations=1)

# %%
fig,ax=plt.subplots(1,2,figsize=(10, 10))
ax[0].imshow(output)
ax[1].imshow(dilated[:,:,0],cmap='gray')

# %%
    contours, hierarchy = cv2.findContours(dilated[:,:,0],  
    cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE) 
print(len(contours))
img_show=cv2.drawContours(img_show, contours, -1, (0, 255, 0), 3) 
img_show.shape
# Out:
# 14
# (491, 960, 3)

# %%
plt.imshow(img_show)

# %%
contour_sizes = [(cv2.contourArea(contour)) for contour in contours]
contour_sizes
# Out:
# [4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 6.0, 4.0, 4.0, 7641.0, 4.0, 4.0, 4.0, 4.0]

# %%
for i in range(len(contour_sizes)):
    if (contour_sizes[i]>2000):
        x, y, w, h = cv2.boundingRect(contours[i])
        x2 = int(x + w)
        y2 = int(y + h)
        
        cv2.rectangle(img_show, (int(x), int(y)), (x + w, y + h), (0, 255, 255), 2)

# %%
plt.imshow(img_show)
